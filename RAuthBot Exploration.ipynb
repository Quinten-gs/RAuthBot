# %%
from urllib.parse import quote_plus
from secrets import CLIENT_ID, CLIENT_SECRET, USERNAME, PASSWD

import praw

QUESTIONS = ["what is", "who is", "what are"]
REPLY_TEMPLATE = "[Let me google that for you](http://lmgtfy.com/?q={})"


def main():
    reddit = praw.Reddit(
        user_agent="RAuthBot (by /u/RAuthBot)",
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        username=USERNAME,
        password=PASSWD,
    )

    subreddit = reddit.subreddit("AskReddit")
    for submission in subreddit.stream.submissions():
        process_submission(submission)


def process_submission(submission):
    # Ignore titles with more than 10 words as they probably are not simple
    # questions.
    if len(submission.title.split()) > 10:
        return

    normalized_title = submission.title.lower()
    for question_phrase in QUESTIONS:
        if question_phrase in normalized_title:
            url_title = quote_plus(submission.title)
            print(url_title)

# %%
main()
# Out:
# What+are+you%2C+as+a+person%2C+without+your+job%3F
# What+are+some+good+aesthetics%3F
# What+is+the+most+boring+thing+you+can+think+of%3F
# What+is+world+high+score+for+chrome+T-Rex+game%3F
# What+is+the+most+disappointing+game+experience+you%27ve+had%3F
# What+are+some+incorrect+history+%E2%80%9Cfacts%E2%80%9D%3F
# What+are+the+best+ways+to+work+online%3F
# What+are+the+signs+of+a+good+personality%3F
# Who+is+the+worst+actor+of+all+time%3F
# What+are+some+of+your+habits+Good+or+bad+%3F
# What+is+Your+Worst+Rejection+Story%3F
# What+are+some+great+hobbies+to+develop+during+this+time%3F
# What+are+the+unwritten+rules+of+reddit%3F
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-1-ea9a9c55cc0f> in main()
#      18
#      19     subreddit = reddit.subreddit("AskReddit")
# ...
